# %% [markdown]
# ## Data Wrangling ##

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# import dataset
kashti=sns.load_dataset("titanic")
ks1= kashti
ks2= kashti
ks=sns.load_dataset("titanic")

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Simple operations (Math Operator)

(kashti["age"]*5).head(10)
# Out:
# 0    110.0
# 1    190.0
# 2    130.0
# 3    175.0
# 4    175.0
# 5      NaN
# 6    270.0
# 7     10.0
# 8    135.0
# 9     70.0
# Name: age, dtype: float64

# %%
# Where missing values are
kashti.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# Use drop.na method
kashti.dropna(subset=["deck"],axis=0,inplace=True)
kashti.shape
# Out:
# (203, 15)

# %%
# Checking again null value
kashti.isnull().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age            19
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# deck            0
# embark_town     2
# alive           0
# alone           0
# dtype: int64

# %%
# to drop na method
kashti=kashti.dropna() # remove na from whole dataframe

kashti.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
kashti.shape
# Out:
# (182, 15)

# %%
# Checking ks1 null values
ks1.isnull().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age            19
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# deck            0
# embark_town     2
# alive           0
# alone           0
# dtype: int64

# %% [markdown]
# ## Replacing missing values with the average of that column ##

# %%
# finding an average mean
mean=ks1["age"].mean()
mean
# Out:
# 35.77945652173913

# %%
# Replacing nan with mean of the data updating as well
ks1["age"]=ks1["age"].replace(np.nan,mean)

# %%
# Checking ks1 null values
ks1.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
# finding an average mean
mode=ks1["deck"].mode()
mode
# Out:
# 0    C
# Name: deck, dtype: category
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
ks1.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
# to dropna method
ks1=ks1.dropna()
ks1.isnull().sum() # checking null values
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
# know the datatype and convert it into the new one
ks1.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# use this method to convert datatype from one to another format
kashti["survived"]=kashti["survived"].astype("float64")
kashti.dtypes
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14028\373049746.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kashti["survived"]=kashti["survived"].astype("float64")
# survived        float64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# here we will convert the age into days instead of years
ks1["age"]=ks1["age"]*365
ks1.head(10)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14028\3782762498.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks1["age"]=ks1["age"]*365
#     survived  pclass     sex          age  sibsp  parch      fare embarked  \
# 1          1       1  female  13870.00000      1      0   71.2833        C
# 3          1       1  female  12775.00000      1      0   53.1000        S
# 6          0       1    male  19710.00000      0      0   51.8625        S
# 10         1       3  female   1460.00000      1      1   16.7000        S
# 11         1       1  female  21170.00000      0      0   26.5500        S
# 21         1       2    male  12410.00000      0      0   13.0000        S
# 23         1       1    male  10220.00000      0      0   35.5000        S
# 27         0       1    male   6935.00000      3      2  263.0000        S
# 31         1       1  female  13059.50163      1      0  146.5208        C
# 52         1       1  female  17885.00000      1      0   76.7292        C
#
#      class    who  adult_male deck  embark_town alive  alone
# 1    First  woman       False    C    Cherbourg   yes  False
# 3    First  woman       False    C  Southampton   yes  False
# 6    First    man        True    E  Southampton    no   True
# 10   Third  child       False    G  Southampton   yes  False
# 11   First  woman       False    C  Southampton   yes   True
# 21  Second    man        True    D  Southampton   yes   True
# 23   First    man        True    A  Southampton   yes   True
# 27   First    man        True    C  Southampton    no  False
# 31   First  woman       False    B    Cherbourg   yes  False
# 52   First  woman       False    D    Cherbourg   yes  False

# %%
# Always rename afterwards
ks1.rename(columns={"age":"age in days"},inplace=True)
ks1.head()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14028\353484439.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks1.rename(columns={"age":"age in days"},inplace=True)
#     survived  pclass     sex  age in days  sibsp  parch     fare embarked  \
# 1          1       1  female      13870.0      1      0  71.2833        C
# 3          1       1  female      12775.0      1      0  53.1000        S
# 6          0       1    male      19710.0      0      0  51.8625        S
# 10         1       3  female       1460.0      1      1  16.7000        S
# 11         1       1  female      21170.0      0      0  26.5500        S
#
#     class    who  adult_male deck  embark_town alive  alone
# 1   First  woman       False    C    Cherbourg   yes  False
# 3   First  woman       False    C  Southampton   yes  False
# 6   First    man        True    E  Southampton    no   True
# 10  Third  child       False    G  Southampton   yes  False
# 11  First  woman       False    C  Southampton   yes   True

# %% [markdown]
# ## *Data Normalization* ##

# %%
ks1=ks1[["age in days","fare"]]
ks1.head()
# Out:
#     age in days     fare
# 1       13870.0  71.2833
# 3       12775.0  53.1000
# 6       19710.0  51.8625
# 10       1460.0  16.7000
# 11      21170.0  26.5500

# %% [markdown]
# ## Method of Normalization ##

# %% [markdown]
# 1. Simple feature scaling
#         x(new)=x(old)/x(max)
# 2. Min-Max Method
# 3. z-score standard score -3 to +3
# 4. Log transformation

# %%
# Simple feature scaling
ks1["fare"]=ks1["fare"]/ks1["fare"].max()
ks1["age in days"]=ks1["age in days"]/ks1["age in days"].max()
ks1.head()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14028\2274544920.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks1["fare"]=ks1["fare"]/ks1["fare"].max()
# C:\Users\hp\AppData\Local\Temp\ipykernel_14028\2274544920.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks1["age in days"]=ks1["age in days"]/ks1["age in days"].max()
#     age in days      fare
# 1        0.4750  0.139136
# 3        0.4375  0.103644
# 6        0.6750  0.101229
# 10       0.0500  0.032596
# 11       0.7250  0.051822

# %% [markdown]
# ## *MIN-Max Method* ##

# %%
ks1["fare"]= (ks1["fare"]-ks1["fare"].min())/(ks1["fare"].max()-ks1["fare"].min())
ks1.head()
# Out:
#     age in days      fare
# 1        0.4750  0.139136
# 3        0.4375  0.103644
# 6        0.6750  0.101229
# 10       0.0500  0.032596
# 11       0.7250  0.051822

# %% [markdown]
# # z-score Method #

# %%
# Standard score
ks1["fare"]= (ks1["fare"]-ks1["fare"].mean())/ks1["fare"].std()
ks1.head()
# Out:
#     age in days      fare
# 1        0.4750 -0.067057
# 3        0.4375 -0.309853
# 6        0.6750 -0.326377
# 10       0.0500 -0.795891
# 11       0.7250 -0.664367

# %% [markdown]
# ## *Log Transformation* ##

# %%
ks.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
ks["fare"] = np.log(ks["fare"])
ks.head()
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  22.0      1      0  1.981001        S  Third
# 1         1       1  female  38.0      1      0  4.266662        C  First
# 2         1       3  female  26.0      0      0  2.070022        S  Third
# 3         1       1  female  35.0      1      0  3.972177        S  First
# 4         0       3    male  35.0      0      0  2.085672        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # *Binning* #

# %%
bins = np.linspace(min(kashti["age"]),max(kashti["age"]),4)
age_groups = ("low","medium","high")
kashti["age"] = pd.cut(kashti["age"],bins,labels=age_groups,include_lowest=True)
kashti["age"]
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14028\68731808.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kashti["age"] = pd.cut(kashti["age"],bins,labels=age_groups,include_lowest=True)
# 1      medium
# 3      medium
# 6        high
# 10        low
# 11       high
#         ...
# 871    medium
# 872    medium
# 879      high
# 887       low
# 889       low
# Name: age, Length: 182, dtype: category
# Categories (3, object): ['low' < 'medium' < 'high']

# %% [markdown]
# ## *Converting categories into dummies* ##

# %% [markdown]
# - easy to use for computation
# - Male, Female (0,1)

# %%
dummy=pd.get_dummies(ks["sex"])
dummy.head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
ks=ks.merge(dummy,left_index=True,right_index=True)
ks.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  22.0      1      0  1.981001        S  Third
# 1         1       1  female  38.0      1      0  4.266662        C  First
# 2         1       3  female  26.0      0      0  2.070022        S  Third
# 3         1       1  female  35.0      1      0  3.972177        S  First
# 4         0       3    male  35.0      0      0  2.085672        S  Third
#
#      who  ...  deck  embark_town alive  alone  female_x  male_x  female_x  \
# 0    man  ...   NaN  Southampton    no  False         0       1         0
# 1  woman  ...     C    Cherbourg   yes  False         1       0         1
# 2  woman  ...   NaN  Southampton   yes   True         1       0         1
# 3  woman  ...     C  Southampton   yes  False         1       0         1
# 4    man  ...   NaN  Southampton    no   True         0       1         0
#
#    male_x  female_y  male_y
# 0       1         0       1
# 1       0         1       0
# 2       0         1       0
# 3       0         1       0
# 4       1         0       1
#
# [5 rows x 21 columns]

# %%
ks=pd.concat([ks,dummy],axis=1)
ks.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  22.0      1      0  1.981001        S  Third
# 1         1       1  female  38.0      1      0  4.266662        C  First
# 2         1       3  female  26.0      0      0  2.070022        S  Third
# 3         1       1  female  35.0      1      0  3.972177        S  First
# 4         0       3    male  35.0      0      0  2.085672        S  Third
#
#      who  ... female_x male_x female_x male_x  female_y  male_y  female  male  \
# 0    man  ...        0      1        0      1         0       1       0     1
# 1  woman  ...        1      0        1      0         1       0       1     0
# 2  woman  ...        1      0        1      0         1       0       1     0
# 3  woman  ...        1      0        1      0         1       0       1     0
# 4    man  ...        0      1        0      1         0       1       0     1
#
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1
#
# [5 rows x 25 columns]

# %%
ks.rename(columns={"male female":"0,1"},inplace=True)
ks.head()
# Out:
#    survived  pclass     0,1   age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  22.0      1      0  1.981001        S  Third
# 1         1       1  female  38.0      1      0  4.266662        C  First
# 2         1       3  female  26.0      0      0  2.070022        S  Third
# 3         1       1  female  35.0      1      0  3.972177        S  First
# 4         0       3    male  35.0      0      0  2.085672        S  Third
#
#      who  ... female_x male_x female_x male_x  female_y  male_y  female  male  \
# 0    man  ...        0      1        0      1         0       1       0     1
# 1  woman  ...        1      0        1      0         1       0       1     0
# 2  woman  ...        1      0        1      0         1       0       1     0
# 3  woman  ...        1      0        1      0         1       0       1     0
# 4    man  ...        0      1        0      1         0       1       0     1
#
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1
#
# [5 rows x 25 columns]
